# %% [markdown]
# #### Module 0 Map Generation

# %%
from M0_Class_Map_Road import Map

# %%
# Create a based map
M = Map('Data/AA_Map_Final.gpkg')
# Experience a snow event
M.Experience_Snow(6)

# %% [markdown]
# #### Module 1 Trip Simulation

# %%
from M1_Trip_Generation_Module import Generate_Trips
import time

# %%
#
start_time = time.time()

# Generate trips
Generate_Trips(M, 'Data/your_locations.csv', 'Data/your_destinations.csv')

#
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# --- 72.43742084503174 seconds ---

# %% [markdown]
# #### Module 2 Plowing Simulation

# %%
from M2_Plowing_Simulatoin_Module import Run_Snowplow_Simulation

# %%
#
start_time = time.time()

# Simulation Plowing Time
Run_Snowplow_Simulation(1, [310], 15, M, 720)

#
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# --- 26.87697196006775 seconds ---

# %% [markdown]
# #### Module 3 Travel Simulation

# %%
from M3_Travel_Simulation_Module import Run_Travel_Simulation

# %%
#
start_time = time.time()

# Simulate Travel Time
result = Run_Travel_Simulation(M)

#
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# --- 3.779238700866699 seconds ---

# %%
result

# %%
list(M.roads.plow_time)
# Out:
# inf

# %%
M.trips
# Out:
# [{'start_latitude': 42.286037,
#   'start_longitude': -83.777836,
#   'destination_latitude': 42.2854541,
#   'destination_longitude': -83.7788879,
#   'path_to_store': [138],
#   'path_from_store': [138],
#   'duration': 14,
#   'trip_start_time': 353.33808894316957},
#  {'start_latitude': 42.254471,
#   'start_longitude': -83.730105,
#   'destination_latitude': 42.258541,
#   'destination_longitude': -83.713074,
#   'path_to_store': [234, 64],
#   'path_from_store': [64, 234],
#   'duration': 24,
#   'trip_start_time': 312.89046153360204},
#  {'start_latitude': 42.279392,
#   'start_longitude': -83.748403,
#   'destination_latitude': 42.2794636,
#   'destination_longitude': -83.7405186,
#   'path_to_store': [215, 230, 303, 406, 388, 144, 201, 129],
#   'path_from_store': [129, 201, 144, 388, 406, 303, 230, 215],
#   'duration': 23,
#   'trip_start_time': 266.5425681522658},
#  {'start_latitude': 42.289086,
#   'start_longitude': -83.754825,
#   'destination_latitude': 42.2854541,
#   'destination_longitude': -83.7788879,
#   'path_to_store': [246, 228, 65, 10, 248, 138],
#   'path_from_store': [138, 248, 10, 65, 228, 246],
#   'duration': 32,
#   'trip_start_time': 251.49715992149268},
#  {'start_latitude': 42.261958,
#   'start_longitude': -83.730595,
#   'destination_latitude': 42.258541,
#   'destination_longitude': -83.713074,
#   'path_to_store': [234, 64],
#   'path_from_store': [64, 234],
#   'duration': 17,
#   'trip_start_time': 159.64389734527245},
#  {'start_latitude': 42.254238,
#   'start_longitude': -83.689959,
#   'destination_latitude': 42.2582907,
#   'destination_longitude': -83.6888898,
#   'path_to_store': [60],
#   'path_from_store': [60],
#   'duration': 18,
#   'trip_start_time': 50.19722915057583},
#  {'start_latitude': 42.273794,
#   'start_longitude': -83.790052,
#   'destination_latitude': 42.2774847,
#   'destination_longitude': -83.7822065,
#   'path_to_store': [190, 22],
#   'path_from_store': [22, 190],
#   'duration': 24,
#   'trip_start_time': 275.6888333875459},
#  {'start_latitude': 42.274338,
#   'start_longitude': -83.774061,
#   'destination_latitude': 42.2774847,
#   'destination_longitude': -83.7822065,
#   'path_to_store': [19, 343, 190, 22],
#   'path_from_store': [22, 190, 343, 19],
#   'duration': 22,
#   'trip_start_time': 292.84973364464355},
#  {'start_latitude': 42.253771,
#   'start_longitude': -83.756276,
#   'destination_latitude': 42.24818,
#   'destination_longitude': -83.758339,
#   'path_to_store': [23, 279],
#   'path_from_store': [279, 23],
#   'duration': 25,
#   'trip_start_time': 107.55335922461836},
#  {'start_latitude': 42.268785,
#   'start_longitude': -83.739097,
#   'destination_latitude': 42.258541,
#   'destination_longitude': -83.713074,
#   'path_to_store': [145, 267, 234, 64],
#   'path_from_store': [64, 234, 267, 145],
#   'duration': 18,
#   'trip_start_time': 505.6233099534244},
#  {'start_latitude': 42.266848,
#   'start_longitude': -83.767034,
#   'destination_latitude': 42.2774847,
#   'destination_longitude': -83.7822065,
#   'path_to_store': [78, 19, 343, 190, 22],
#   'path_from_store': [22, 190, 343, 19, 78],
#   'duration': 24,
#   'trip_start_time': 179.76471547523616},
#  {'start_latitude': 42.292803,
#   'start_longitude': -83.688445,
#   'destination_latitude': 42.3060503,
#   'destination_longitude': -83.6910262,
#   'path_to_store': [295, 412, 161],
#   'path_from_store': [161, 412, 295],
#   'duration': 21,
#   'trip_start_time': 490.15084208069266},
#  {'start_latitude': 42.254551,
#   'start_longitude': -83.696505,
#   'destination_latitude': 42.2579937,
#   'destination_longitude': -83.6982439,
#   'path_to_store': [106],
#   'path_from_store': [106],
#   'duration': 17,
#   'trip_start_time': 488.3405766778883},
#  {'start_latitude': 42.269637,
#   'start_longitude': -83.762957,
#   'destination_latitude': 42.258541,
#   'destination_longitude': -83.713074,
#   'path_to_store': [114, 407, 145, 267, 234, 64],
#   'path_from_store': [64, 234, 267, 145, 407, 114],
#   'duration': 20,
#   'trip_start_time': 507.96782520160815},
#  {'start_latitude': 42.253547,
#   'start_longitude': -83.761863,
#   'destination_latitude': 42.24818,
#   'destination_longitude': -83.758339,
#   'path_to_store': [141, 352, 170, 23, 279],
#   'path_from_store': [279, 23, 170, 352, 141],
#   'duration': 27,
#   'trip_start_time': 461.8384030251131},
#  {'start_latitude': 42.241938,
#   'start_longitude': -83.728449,
#   'destination_latitude': 42.24818,
#   'destination_longitude': -83.758339,
#   'path_to_store': [238, 142, 108, 154, 279],
#   'path_from_store': [279, 154, 108, 142, 238],
#   'duration': 15,
#   'trip_start_time': 189.9743080900187},
#  {'start_latitude': 42.289651,
#   'start_longitude': -83.695333,
#   'destination_latitude': 42.3060503,
#   'destination_longitude': -83.6910262,
#   'path_to_store': [96, 349, 161],
#   'path_from_store': [161, 349, 96],
#   'duration': 21,
#   'trip_start_time': 158.38347167570436},
#  {'start_latitude': 42.289263,
#   'start_longitude': -83.738119,
#   'destination_latitude': 42.3047316,
#   'destination_longitude': -83.7087342,
#   'path_to_store': [13, 330, 420, 334, 40],
#   'path_from_store': [40, 334, 420, 330, 13],
#   'duration': 20,
#   'trip_start_time': 458.4525322731574},
#  {'start_latitude': 42.297731,
#   'start_longitude': -83.780194,
#   'destination_latitude': 42.2854541,
#   'destination_longitude': -83.7788879,
#   'path_to_store': [393, 248, 138],
#   'path_from_store': [138, 248, 393],
#   'duration': 30,
#   'trip_start_time': 160.7552753675268},
#  {'start_latitude': 42.28489,
#   'start_longitude': -83.695731,
#   'destination_latitude': 42.3060503,
#   'destination_longitude': -83.6910262,
#   'path_to_store': [96, 349, 161],
#   'path_from_store': [161, 349, 96],
#   'duration': 23,
#   'trip_start_time': 488.070989699595},
#  {'start_latitude': 42.262866,
#   'start_longitude': -83.732311,
#   'destination_latitude': 42.258541,
#   'destination_longitude': -83.713074,
#   'path_to_store': [234, 64],
#   'path_from_store': [64, 234],
#   'duration': 21,
#   'trip_start_time': 425.67321057285363},
#  {'start_latitude': 42.266006,
#   'start_longitude': -83.779561,
#   'destination_latitude': 42.2774847,
#   'destination_longitude': -83.7822065,
#   'path_to_store': [32, 343, 190, 22],
#   'path_from_store': [22, 190, 343, 32],
#   'duration': 19,
#   'trip_start_time': 496.48975409906575},
#  {'start_latitude': 42.257186,
#   'start_longitude': -83.772192,
#   'destination_latitude': 42.2774847,
#   'destination_longitude': -83.7822065,
#   'path_to_store': [208, 3, 190, 22],
#   'path_from_store': [22, 190, 3, 208],
#   'duration': 30,
#   'trip_start_time': 424.11764939043337},
#  {'start_latitude': 42.289324,
#   'start_longitude': -83.782965,
#   'destination_latitude': 42.2849389,
#   'destination_longitude': -83.7816983,
#   'path_to_store': [55],
#   'path_from_store': [55],
#   'duration': 17,
#   'trip_start_time': 434.41411777028037},
#  {'start_latitude': 42.274398,
#   'start_longitude': -83.788028,
#   'destination_latitude': 42.2774847,
#   'destination_longitude': -83.7822065,
#   'path_to_store': [190, 22],
#   'path_from_store': [22, 190],
#   'duration': 14,
#   'trip_start_time': 194.92303254507345},
#  {'start_latitude': 42.285374,
#   'start_longitude': -83.761552,
#   'destination_latitude': 42.2849389,
#   'destination_longitude': -83.7816983,
#   'path_to_store': [156, 329, 4, 55],
#   'path_from_store': [55, 4, 329, 156],
#   'duration': 14,
#   'trip_start_time': 429.6056104760151},
#  {'start_latitude': 42.254205,
#   'start_longitude': -83.694337,
#   'destination_latitude': 42.2579937,
#   'destination_longitude': -83.6982439,
#   'path_to_store': [106],
#   'path_from_store': [106],
#   'duration': 20,
#   'trip_start_time': 223.47617660297186},
#  {'start_latitude': 42.289537,
#   'start_longitude': -83.739666,
#   'destination_latitude': 42.2794636,
#   'destination_longitude': -83.7405186,
#   'path_to_store': [302, 288, 47, 17, 129],
#   'path_from_store': [129, 17, 47, 288, 302],
#   'duration': 25,
#   'trip_start_time': 359.92221953527616},
#  {'start_latitude': 42.287268,
#   'start_longitude': -83.681807,
#   'destination_latitude': 42.3060503,
#   'destination_longitude': -83.6910262,
#   'path_to_store': [199, 96, 349, 161],
#   'path_from_store': [161, 412, 295, 199],
#   'duration': 19,
#   'trip_start_time': 460.91056711618745},
#  {'start_latitude': 42.278251,
#   'start_longitude': -83.755615,
#   'destination_latitude': 42.2849389,
#   'destination_longitude': -83.7816983,
#   'path_to_store': [36, 329, 4, 55],
#   'path_from_store': [55, 4, 329, 36],
#   'duration': 25,
#   'trip_start_time': 344.4598049188344},
#  {'start_latitude': 42.320731,
#   'start_longitude': -83.697766,
#   'destination_latitude': 42.3060503,
#   'destination_longitude': -83.6910262,
#   'path_to_store': [271, 56, 386, 103, 277, 161],
#   'path_from_store': [161, 277, 103, 386, 56, 271],
#   'duration': 13,
#   'trip_start_time': 196.454712864649},
#  {'start_latitude': 42.290817,
#   'start_longitude': -83.775372,
#   'destination_latitude': 42.2854541,
#   'destination_longitude': -83.7788879,
#   'path_to_store': [248, 138],
#   'path_from_store': [138, 248],
#   'duration': 26,
#   'trip_start_time': 403.438542838399},
#  {'start_latitude': 42.274391,
#   'start_longitude': -83.761871,
#   'destination_latitude': 42.2849389,
#   'destination_longitude': -83.7816983,
#   'path_to_store': [83, 36, 329, 4, 55],
#   'path_from_store': [55, 4, 329, 36, 83],
#   'duration': 13,
#   'trip_start_time': 546.3521838430806},
#  {'start_latitude': 42.26337,
#   'start_longitude': -83.733944,
#   'destination_latitude': 42.258541,
#   'destination_longitude': -83.713074,
#   'path_to_store': [66, 234, 64],
#   'path_from_store': [64, 234, 66],
#   'duration': 23,
#   'trip_start_time': 321.3691722256684},
#  {'start_latitude': 42.260143,
#   'start_longitude': -83.780677,
#   'destination_latitude': 42.239491,
#   'destination_longitude': -83.76638,
#   'path_to_store': [242, 418, 308],
#   'path_from_store': [308, 418, 242],
#   'duration': 27,
#   'trip_start_time': 120.64676175232667},
#  {'start_latitude': 42.264389,
#   'start_longitude': -83.775123,
#   'destination_latitude': 42.2774847,
#   'destination_longitude': -83.7822065,
#   'path_to_store': [416, 32, 343, 190, 22],
#   'path_from_store': [22, 190, 343, 32, 416],
#   'duration': 22,
#   'trip_start_time': 528.5638589996007},
#  {'start_latitude': 42.263401,
#   'start_longitude': -83.726159,
#   'destination_latitude': 42.258541,
#   'destination_longitude': -83.713074,
#   'path_to_store': [234, 64],
#   'path_from_store': [64, 234],
#   'duration': 23,
#   'trip_start_time': 314.704567727229},
#  {'start_latitude': 42.299894,
#   'start_longitude': -83.733228,
#   'destination_latitude': 42.3047316,
#   'destination_longitude': -83.7087342,
#   'path_to_store': [177, 330, 420, 334, 40],
#   'path_from_store': [40, 334, 420, 330, 177],
#   'duration': 24,
#   'trip_start_time': 277.4726528694638},
#  {'start_latitude': 42.267343,
#   'start_longitude': -83.760332,
#   'destination_latitude': 42.258541,
#   'destination_longitude': -83.713074,
#   'path_to_store': [114, 407, 145, 267, 234, 64],
#   'path_from_store': [64, 234, 267, 145, 407, 114],
#   'duration': 24,
#   'trip_start_time': 272.62048031078945},
#  {'start_latitude': 42.287983,
#   'start_longitude': -83.786636,
#   'destination_latitude': 42.2774847,
#   'destination_longitude': -83.7822065,
#   'path_to_store': [109, 257, 22],
#   'path_from_store': [22, 257, 109],
#   'duration': 25,
#   'trip_start_time': 238.9349306223742},
#  {'start_latitude': 42.27795,
#   'start_longitude': -83.742539,
#   'destination_latitude': 42.2794636,
#   'destination_longitude': -83.7405186,
#   'path_to_store': [144, 201, 129],
#   'path_from_store': [129, 201, 144],
#   'duration': 21,
#   'trip_start_time': 390.920441848911},
#  {'start_latitude': 42.26639,
#   'start_longitude': -83.71269,
#   'destination_latitude': 42.258541,
#   'destination_longitude': -83.713074,
#   'path_to_store': [166, 319, 64],
#   'path_from_store': [64, 319, 166],
#   'duration': 25,
#   'trip_start_time': 211.94382022761897},
#  {'start_latitude': 42.269888,
#   'start_longitude': -83.771724,
#   'destination_latitude': 42.2774847,
#   'destination_longitude': -83.7822065,
#   'path_to_store': [416, 32, 343, 190, 22],
#   'path_from_store': [22, 190, 343, 32, 416],
#   'duration': 19,
#   'trip_start_time': 527.6284164666089},
#  {'start_latitude': 42.238296,
#   'start_longitude': -83.726248,
#   'destination_latitude': 42.258541,
#   'destination_longitude': -83.713074,
#   'path_to_store': [241, 53, 347, 234, 64],
#   'path_from_store': [64, 234, 347, 53, 241],
#   'duration': 16,
#   'trip_start_time': 352.1562379417839},
#  {'start_latitude': 42.277389,
#   'start_longitude': -83.758201,
#   'destination_latitude': 42.2849389,
#   'destination_longitude': -83.7816983,
#   'path_to_store': [36, 329, 4, 55],
#   'path_from_store': [55, 4, 329, 36],
#   'duration': 24,
#   'trip_start_time': 529.5986289515968},
#  {'start_latitude': 42.253379,
#   'start_longitude': -83.690253,
#   'destination_latitude': 42.2582907,
#   'destination_longitude': -83.6888898,
#   'path_to_store': [60],
#   'path_from_store': [60],
#   'duration': 29,
#   'trip_start_time': 453.6052030450198},
#  {'start_latitude': 42.28727,
#   'start_longitude': -83.681853,
#   'destination_latitude': 42.3060503,
#   'destination_longitude': -83.6910262,
#   'path_to_store': [199, 96, 349, 161],
#   'path_from_store': [161, 412, 295, 199],
#   'duration': 22,
#   'trip_start_time': 402.54971780217437},
#  {'start_latitude': 42.262996,
#   'start_longitude': -83.710212,
#   'destination_latitude': 42.258541,
#   'destination_longitude': -83.713074,
#   'path_to_store': [64],
#   'path_from_store': [64],
#   'duration': 10,
#   'trip_start_time': 168.9792052919529},
#  {'start_latitude': 42.284659,
#   'start_longitude': -83.696673,
#   'destination_latitude': 42.3060503,
#   'destination_longitude': -83.6910262,
#   'path_to_store': [96, 349, 161],
#   'path_from_store': [161, 349, 96],
#   'duration': 19,
#   'trip_start_time': 437.6007544868758},
#  {'start_latitude': 42.266167,
#   'start_longitude': -83.731758,
#   'destination_latitude': 42.258541,
#   'destination_longitude': -83.713074,
#   'path_to_store': [234, 64],
#   'path_from_store': [64, 234],
#   'duration': 13,
#   'trip_start_time': 164.7914791332136},
#  {'start_latitude': 42.264432,
#   'start_longitude': -83.737605,
#   'destination_latitude': 42.258541,
#   'destination_longitude': -83.713074,
#   'path_to_store': [66, 234, 64],
#   'path_from_store': [64, 234, 66],
#   'duration': 17,
#   'trip_start_time': 496.3325247734658},
#  {'start_latitude': 42.25447,
#   'start_longitude': -83.716804,
#   'destination_latitude': 42.258541,
#   'destination_longitude': -83.713074,
#   'path_to_store': [347, 234, 64],
#   'path_from_store': [64, 234, 347],
#   'duration': 18,
#   'trip_start_time': 335.66473890275375},
#  {'start_latitude': 42.273392,
#   'start_longitude': -83.705916,
#   'destination_latitude': 42.258541,
#   'destination_longitude': -83.713074,
#   'path_to_store': [166, 319, 64],
#   'path_from_store': [64, 319, 166],
#   'duration': 22,
#   'trip_start_time': 304.4014091572557},
#  {'start_latitude': 42.258804,
#   'start_longitude': -83.773676,
#   'destination_latitude': 42.2774847,
#   'destination_longitude': -83.7822065,
#   'path_to_store': [208, 3, 190, 22],
#   'path_from_store': [22, 190, 3, 208],
#   'duration': 11,
#   'trip_start_time': 680.4132697882328},
#  {'start_latitude': 42.284632,
#   'start_longitude': -83.768928,
#   'destination_latitude': 42.2849389,
#   'destination_longitude': -83.7816983,
#   'path_to_store': [4, 55],
#   'path_from_store': [55, 4],
#   'duration': 23,
#   'trip_start_time': 252.2431005848133},
#  {'start_latitude': 42.29039,
#   'start_longitude': -83.779909,
#   'destination_latitude': 42.2854541,
#   'destination_longitude': -83.7788879,
#   'path_to_store': [248, 138],
#   'path_from_store': [138, 248],
#   'duration': 21,
#   'trip_start_time': 610.0700882144423},
#  {'start_latitude': 42.295295,
#   'start_longitude': -83.692113,
#   'destination_latitude': 42.3060503,
#   'destination_longitude': -83.6910262,
#   'path_to_store': [96, 349, 161],
#   'path_from_store': [161, 349, 96],
#   'duration': 22,
#   'trip_start_time': 208.49852592661458},
#  {'start_latitude': 42.308053,
#   'start_longitude': -83.699967,
#   'destination_latitude': 42.3047316,
#   'destination_longitude': -83.7087342,
#   'path_to_store': [218, 334, 40],
#   'path_from_store': [40, 334, 218],
#   'duration': 18,
#   'trip_start_time': 627.091719020555},
#  {'start_latitude': 42.282488,
#   'start_longitude': -83.736671,
#   'destination_latitude': 42.2794636,
#   'destination_longitude': -83.7405186,
#   'path_to_store': [97, 79, 17, 129],
#   'path_from_store': [129, 17, 79, 97],
#   'duration': 15,
#   'trip_start_time': 294.6709962775244},
#  {'start_latitude': 42.252884,
#   'start_longitude': -83.686677,
#   'destination_latitude': 42.2582907,
#   'destination_longitude': -83.6888898,
#   'path_to_store': [42, 60],
#   'path_from_store': [60, 42],
#   'duration': 21,
#   'trip_start_time': 306.57767020606985},
#  {'start_latitude': 42.315731,
#   'start_longitude': -83.699931,
#   'destination_latitude': 42.3060503,
#   'destination_longitude': -83.6910262,
#   'path_to_store': [220, 344, 349, 161],
#   'path_from_store': [161, 349, 344, 220],
#   'duration': 18,
#   'trip_start_time': 606.9868502425526},
#  {'start_latitude': 42.271165,
#   'start_longitude': -83.730309,
#   'destination_latitude': 42.258541,
#   'destination_longitude': -83.713074,
#   'path_to_store': [350, 289, 64],
#   'path_from_store': [64, 289, 350],
#   'duration': 21,
#   'trip_start_time': 461.5749529524019},
#  {'start_latitude': 42.310327,
#   'start_longitude': -83.708205,
#   'destination_latitude': 42.3047316,
#   'destination_longitude': -83.7087342,
#   'path_to_store': [253, 40],
#   'path_from_store': [40, 253],
#   'duration': 24,
#   'trip_start_time': 233.5825945367596},
#  {'start_latitude': 42.312518,
#   'start_longitude': -83.691843,
#   'destination_latitude': 42.3060503,
#   'destination_longitude': -83.6910262,
#   'path_to_store': [220, 344, 349, 161],
#   'path_from_store': [161, 349, 344, 220],
#   'duration': 15,
#   'trip_start_time': 182.27790117747531},
#  {'start_latitude': 42.286007,
#   'start_longitude': -83.691709,
#   'destination_latitude': 42.3060503,
#   'destination_longitude': -83.6910262,
#   'path_to_store': [96, 349, 161],
#   'path_from_store': [161, 349, 96],
#   'duration': 24,
#   'trip_start_time': 77.7891283002332},
#  {'start_latitude': 42.27142,
#   'start_longitude': -83.701573,
#   'destination_latitude': 42.258541,
#   'destination_longitude': -83.713074,
#   'path_to_store': [27, 166, 319, 64],
#   'path_from_store': [64, 319, 166, 27],
#   'duration': 20,
#   'trip_start_time': 327.18721342329275},
#  {'start_latitude': 42.263298,
#   'start_longitude': -83.729303,
#   'destination_latitude': 42.258541,
#   'destination_longitude': -83.713074,
#   'path_to_store': [234, 64],
#   'path_from_store': [64, 234],
#   'duration': 17,
#   'trip_start_time': 333.5861463818319},
#  {'start_latitude': 42.264773,
#   'start_longitude': -83.729107,
#   'destination_latitude': 42.258541,
#   'destination_longitude': -83.713074,
#   'path_to_store': [234, 64],
#   'path_from_store': [64, 234],
#   'duration': 22,
#   'trip_start_time': 664.1199697168012},
#  {'start_latitude': 42.290947,
#   'start_longitude': -83.769493,
#   'destination_latitude': 42.2854541,
#   'destination_longitude': -83.7788879,
#   'path_to_store': [10, 248, 138],
#   'path_from_store': [138, 248, 10],
#   'duration': 18,
#   'trip_start_time': 332.28322742562875},
#  {'start_latitude': 42.25898,
#   'start_longitude': -83.768023,
#   'destination_latitude': 42.24818,
#   'destination_longitude': -83.758339,
#   'path_to_store': [141, 352, 170, 23, 279],
#   'path_from_store': [279, 23, 170, 352, 141],
#   'duration': 27,
#   'trip_start_time': 554.1861837918544},
#  {'start_latitude': 42.244656,
#   'start_longitude': -83.693654,
#   'destination_latitude': 42.2582907,
#   'destination_longitude': -83.6888898,
#   'path_to_store': [113, 60],
#   'path_from_store': [60, 113],
#   'duration': 19,
#   'trip_start_time': 320.21606197705285},
#  {'start_latitude': 42.322364,
#   'start_longitude': -83.714322,
#   'destination_latitude': 42.3047316,
#   'destination_longitude': -83.7087342,
#   'path_to_store': [63, 354, 293, 371, 253, 40],
#   'path_from_store': [40, 253, 371, 293, 354, 63],
#   'duration': 22,
#   'trip_start_time': 128.94584489650344},
#  {'start_latitude': 42.322098,
#   'start_longitude': -83.721724,
#   'destination_latitude': 42.3047316,
#   'destination_longitude': -83.7087342,
#   'path_to_store': [333, 63, 354, 293, 371, 253, 40],
#   'path_from_store': [40, 253, 371, 293, 354, 63, 333],
#   'duration': 27,
#   'trip_start_time': 143.19977714250592},
#  {'start_latitude': 42.304889,
#   'start_longitude': -83.704868,
#   'destination_latitude': 42.3047316,
#   'destination_longitude': -83.7087342,
#   'path_to_store': [218, 334, 40],
#   'path_from_store': [40, 334, 218],
#   'duration': 17,
#   'trip_start_time': 407.20681247020605},
#  {'start_latitude': 42.235464,
#   'start_longitude': -83.710107,
#   'destination_latitude': 42.2582907,
#   'destination_longitude': -83.6888898,
#   'path_to_store': [219, 100, 113, 60],
#   'path_from_store': [60, 113, 100, 219],
#   'duration': 10,
#   'trip_start_time': 429.22681777189916},
#  {'start_latitude': 42.248388,
#   'start_longitude': -83.717969,
#   'destination_latitude': 42.258541,
#   'destination_longitude': -83.713074,
#   'path_to_store': [347, 234, 64],
#   'path_from_store': [64, 234, 347],
#   'duration': 20,
#   'trip_start_time': 479.0120084331262},
#  {'start_latitude': 42.280941,
#   'start_longitude': -83.696274,
#   'destination_latitude': 42.3060503,
#   'destination_longitude': -83.6910262,
#   'path_to_store': [35, 84, 96, 349, 161],
#   'path_from_store': [161, 349, 96, 84, 35],
#   'duration': 22,
#   'trip_start_time': 508.6766289789738},
#  {'start_latitude': 42.251691,
#   'start_longitude': -83.76947,
#   'destination_latitude': 42.24818,
#   'destination_longitude': -83.758339,
#   'path_to_store': [57, 250, 279],
#   'path_from_store': [279, 250, 57],
#   'duration': 26,
#   'trip_start_time': 162.2249734588987},
#  {'start_latitude': 42.288791,
#   'start_longitude': -83.75311,
#   'destination_latitude': 42.2849389,
#   'destination_longitude': -83.7816983,
#   'path_to_store': [264, 49, 156, 329, 4, 55],
#   'path_from_store': [55, 4, 329, 156, 49, 264],
#   'duration': 18,
#   'trip_start_time': 464.02850475489856},
#  {'start_latitude': 42.247391,
#   'start_longitude': -83.753596,
#   'destination_latitude': 42.24818,
#   'destination_longitude': -83.758339,
#   'path_to_store': [180, 154, 279],
#   'path_from_store': [279, 154, 180],
#   'duration': 27,
#   'trip_start_time': 468.99239894724576},
#  {'start_latitude': 42.246847,
#   'start_longitude': -83.706061,
#   'destination_latitude': 42.2582907,
#   'destination_longitude': -83.6888898,
#   'path_to_store': [219, 100, 113, 60],
#   'path_from_store': [60, 113, 100, 219],
#   'duration': 17,
#   'trip_start_time': 408.9803645235078},
#  {'start_latitude': 42.276302,
#   'start_longitude': -83.72852,
#   'destination_latitude': 42.258541,
#   'destination_longitude': -83.713074,
#   'path_to_store': [346, 289, 64],
#   'path_from_store': [64, 289, 346],
#   'duration': 25,
#   'trip_start_time': 84.67760064294878},
#  {'start_latitude': 42.258159,
#   'start_longitude': -83.768002,
#   'destination_latitude': 42.24818,
#   'destination_longitude': -83.758339,
#   'path_to_store': [141, 352, 170, 23, 279],
#   'path_from_store': [279, 23, 170, 352, 141],
#   'duration': 16,
#   'trip_start_time': 149.713651129255},
#  {'start_latitude': 42.287308,
#   'start_longitude': -83.693073,
#   'destination_latitude': 42.3060503,
#   'destination_longitude': -83.6910262,
#   'path_to_store': [96, 349, 161],
#   'path_from_store': [161, 349, 96],
#   'duration': 18,
#   'trip_start_time': 452.5697281220724},
#  {'start_latitude': 42.27214,
#   'start_longitude': -83.751952,
#   'destination_latitude': 42.258541,
#   'destination_longitude': -83.713074,
#   'path_to_store': [192, 204, 267, 234, 64],
#   'path_from_store': [64, 234, 267, 204, 192],
#   'duration': 28,
#   'trip_start_time': 355.21618937870767},
#  {'start_latitude': 42.262888,
#   'start_longitude': -83.774131,
#   'destination_latitude': 42.2774847,
#   'destination_longitude': -83.7822065,
#   'path_to_store': [416, 32, 343, 190, 22],
#   'path_from_store': [22, 190, 343, 32, 416],
#   'duration': 18,
#   'trip_start_time': 476.6229237425056},
#  {'start_latitude': 42.291352,
#   'start_longitude': -83.741115,
#   'destination_latitude': 42.2794636,
#   'destination_longitude': -83.7405186,
#   'path_to_store': [194, 302, 288, 47, 17, 129],
#   'path_from_store': [129, 17, 47, 288, 302, 194],
#   'duration': 17,
#   'trip_start_time': 220.18238999206892},
#  {'start_latitude': 42.271075,
#   'start_longitude': -83.772744,
#   'destination_latitude': 42.2774847,
#   'destination_longitude': -83.7822065,
#   'path_to_store': [416, 32, 343, 190, 22],
#   'path_from_store': [22, 190, 343, 32, 416],
#   'duration': 23,
#   'trip_start_time': 531.4583146253804},
#  {'start_latitude': 42.279415,
#   'start_longitude': -83.791105,
#   'destination_latitude': 42.2860183,
#   'destination_longitude': -83.8411669,
#   'path_to_store': [188, 254, 335, 73],
#   'path_from_store': [73, 335, 254, 188],
#   'duration': 24,
#   'trip_start_time': 542.9813669814498},
#  {'start_latitude': 42.281114,
#   'start_longitude': -83.775737,
#   'destination_latitude': 42.2849389,
#   'destination_longitude': -83.7816983,
#   'path_to_store': [363, 4, 55],
#   'path_from_store': [55, 4, 363],
#   'duration': 18,
#   'trip_start_time': 135.66750838975003},
#  {'start_latitude': 42.261121,
#   'start_longitude': -83.703165,
#   'destination_latitude': 42.258541,
#   'destination_longitude': -83.713074,
#   'path_to_store': [319, 64],
#   'path_from_store': [64, 319],
#   'duration': 23,
#   'trip_start_time': 159.24586557682076},
#  {'start_latitude': 42.24258,
#   'start_longitude': -83.721638,
#   'destination_latitude': 42.258541,
#   'destination_longitude': -83.713074,
#   'path_to_store': [53, 347, 234, 64],
#   'path_from_store': [64, 234, 347, 53],
#   'duration': 21,
#   'trip_start_time': 50.55914170888636},
#  {'start_latitude': 42.272578,
#   'start_longitude': -83.713555,
#   'destination_latitude': 42.258541,
#   'destination_longitude': -83.713074,
#   'path_to_store': [166, 319, 64],
#   'path_from_store': [64, 319, 166],
#   'duration': 13,
#   'trip_start_time': 258.9966775223195},
#  {'start_latitude': 42.241735,
#   'start_longitude': -83.72132,
#   'destination_latitude': 42.258541,
#   'destination_longitude': -83.713074,
#   'path_to_store': [53, 347, 234, 64],
#   'path_from_store': [64, 234, 347, 53],
#   'duration': 19,
#   'trip_start_time': 304.62326445526134},
#  {'start_latitude': 42.314676,
#   'start_longitude': -83.690483,
#   'destination_latitude': 42.3060503,
#   'destination_longitude': -83.6910262,
#   'path_to_store': [220, 344, 349, 161],
#   'path_from_store': [161, 349, 344, 220],
#   'duration': 19,
#   'trip_start_time': 416.66660509772294},
#  {'start_latitude': 42.261572,
#   'start_longitude': -83.687977,
#   'destination_latitude': 42.2579937,
#   'destination_longitude': -83.6982439,
#   'path_to_store': [118, 179, 146, 106],
#   'path_from_store': [106, 146, 179, 118],
#   'duration': 15,
#   'trip_start_time': 210.16830350715807},
#  {'start_latitude': 42.295044,
#   'start_longitude': -83.771662,
#   'destination_latitude': 42.2854541,
#   'destination_longitude': -83.7788879,
#   'path_to_store': [65, 10, 248, 138],
#   'path_from_store': [138, 248, 10, 65],
#   'duration': 25,
#   'trip_start_time': 396.9933543876427},
#  {'start_latitude': 42.265546,
#   'start_longitude': -83.778865,
#   'destination_latitude': 42.2774847,
#   'destination_longitude': -83.7822065,
#   'path_to_store': [32, 343, 190, 22],
#   'path_from_store': [22, 190, 343, 32],
#   'duration': 20,
#   'trip_start_time': 309.28840015560047},
#  {'start_latitude': 42.284622,
#   'start_longitude': -83.767049,
#   'destination_latitude': 42.2849389,
#   'destination_longitude': -83.7816983,
#   'path_to_store': [4, 55],
#   'path_from_store': [55, 4],
#   'duration': 26,
#   'trip_start_time': 426.9901432049368},
#  {'start_latitude': 42.258047,
#   'start_longitude': -83.725423,
#   'destination_latitude': 42.258541,
#   'destination_longitude': -83.713074,
#   'path_to_store': [234, 64],
#   'path_from_store': [64, 234],
#   'duration': 19,
#   'trip_start_time': 309.90047248117025},
#  {'start_latitude': 42.296895,
#   'start_longitude': -83.777801,
#   'destination_latitude': 42.2854541,
#   'destination_longitude': -83.7788879,
#   'path_to_store': [248, 138],
#   'path_from_store': [138, 248],
#   'duration': 18,
#   'trip_start_time': 563.271389215953},
#  {'start_latitude': 42.286089,
#   'start_longitude': -83.680018,
#   'destination_latitude': 42.3060503,
#   'destination_longitude': -83.6910262,
#   'path_to_store': [199, 96, 349, 161],
#   'path_from_store': [161, 412, 295, 199],
#   'duration': 27,
#   'trip_start_time': 419.92749777620406},
#  {'start_latitude': 42.256346,
#   'start_longitude': -83.727265,
#   'destination_latitude': 42.258541,
#   'destination_longitude': -83.713074,
#   'path_to_store': [234, 64],
#   'path_from_store': [64, 234],
#   'duration': 21,
#   'trip_start_time': 239.203222736221},
#  {'start_latitude': 42.312744,
#   'start_longitude': -83.716873,
#   'destination_latitude': 42.3047316,
#   'destination_longitude': -83.7087342,
#   'path_to_store': [385, 293, 371, 253, 40],
#   'path_from_store': [40, 253, 371, 293, 385],
#   'duration': 15,
#   'trip_start_time': 489.0132083995518},
#  {'start_latitude': 42.266697,
#   'start_longitude': -83.737337,
#   'destination_latitude': 42.258541,
#   'destination_longitude': -83.713074,
#   'path_to_store': [368, 66, 234, 64],
#   'path_from_store': [64, 234, 66, 368],
#   'duration': 24,
#   'trip_start_time': 507.0903951366953},
#  {'start_latitude': 42.264536,
#   'start_longitude': -83.770031,
#   'destination_latitude': 42.2774847,
#   'destination_longitude': -83.7822065,
#   'path_to_store': [78, 19, 343, 190, 22],
#   'path_from_store': [22, 190, 343, 19, 78],
#   'duration': 27,
#   'trip_start_time': 429.4612201082199},
#  {'start_latitude': 42.28694,
#   'start_longitude': -83.768098,
#   'destination_latitude': 42.2854541,
#   'destination_longitude': -83.7788879,
#   'path_to_store': [10, 248, 138],
#   'path_from_store': [138, 248, 10],
#   'duration': 30,
#   'trip_start_time': 345.76729512685506},
#  {'start_latitude': 42.249262,
#   'start_longitude': -83.703245,
#   'destination_latitude': 42.2582907,
#   'destination_longitude': -83.6888898,
#   'path_to_store': [261, 100, 113, 60],
#   'path_from_store': [60, 113, 100, 261],
#   'duration': 15,
#   'trip_start_time': 251.69707338870327},
#  {'start_latitude': 42.270474,
#   'start_longitude': -83.753606,
#   'destination_latitude': 42.258541,
#   'destination_longitude': -83.713074,
#   'path_to_store': [407, 145, 267, 234, 64],
#   'path_from_store': [64, 234, 267, 145, 407],
#   'duration': 22,
#   'trip_start_time': 155.83344491733016},
#  {'start_latitude': 42.293633,
#   'start_longitude': -83.761735,
#   'destination_latitude': 42.2854541,
#   'destination_longitude': -83.7788879,
#   'path_to_store': [228, 65, 10, 248, 138],
#   'path_from_store': [138, 248, 10, 65, 228],
#   'duration': 29,
#   'trip_start_time': 180.48653165275326},
#  {'start_latitude': 42.288986,
#   'start_longitude': -83.778752,
#   'destination_latitude': 42.2854541,
#   'destination_longitude': -83.7788879,
#   'path_to_store': [138],
#   'path_from_store': [138],
#   'duration': 22,
#   'trip_start_time': 260.48468902776125},
#  {'start_latitude': 42.278582,
#   'start_longitude': -83.764156,
#   'destination_latitude': 42.2849389,
#   'destination_longitude': -83.7816983,
#   'path_to_store': [4, 55],
#   'path_from_store': [55, 4],
#   'duration': 17,
#   'trip_start_time': 341.32586146385745},
#  {'start_latitude': 42.275805,
#   'start_longitude': -83.754499,
#   'destination_latitude': 42.2849389,
#   'destination_longitude': -83.7816983,
#   'path_to_store': [227, 83, 36, 329, 4, 55],
#   'path_from_store': [55, 4, 329, 36, 83, 227],
#   'duration': 20,
#   'trip_start_time': 454.64503638037974},
#  {'start_latitude': 42.291248,
#   'start_longitude': -83.693183,
#   'destination_latitude': 42.3060503,
#   'destination_longitude': -83.6910262,
#   'path_to_store': [96, 349, 161],
#   'path_from_store': [161, 349, 96],
#   'duration': 16,
#   'trip_start_time': 508.223892905468},
#  {'start_latitude': 42.245086,
#   'start_longitude': -83.728343,
#   'destination_latitude': 42.24818,
#   'destination_longitude': -83.758339,
#   'path_to_store': [238, 142, 108, 154, 279],
#   'path_from_store': [279, 154, 108, 142, 238],
#   'duration': 27,
#   'trip_start_time': 218.02302714124536},
#  {'start_latitude': 42.313713,
#   'start_longitude': -83.733784,
#   'destination_latitude': 42.3047316,
#   'destination_longitude': -83.7087342,
#   'path_to_store': [54, 177, 330, 420, 334, 40],
#   'path_from_store': [40, 334, 420, 330, 177, 54],
#   'duration': 24,
#   'trip_start_time': 290.6280800967808},
#  {'start_latitude': 42.274294,
#   'start_longitude': -83.785917,
#   'destination_latitude': 42.2774847,
#   'destination_longitude': -83.7822065,
#   'path_to_store': [190, 22],
#   'path_from_store': [22, 190],
#   'duration': 14,
#   'trip_start_time': 438.9417822531889},
#  {'start_latitude': 42.292069,
#   'start_longitude': -83.755286,
#   'destination_latitude': 42.2854541,
#   'destination_longitude': -83.7788879,
#   'path_to_store': [246, 228, 65, 10, 248, 138],
#   'path_from_store': [138, 248, 10, 65, 228, 246],
#   'duration': 25,
#   'trip_start_time': 539.2848768104643},
#  {'start_latitude': 42.272508,
#   'start_longitude': -83.77439,
#   'destination_latitude': 42.2774847,
#   'destination_longitude': -83.7822065,
#   'path_to_store': [19, 343, 190, 22],
#   'path_from_store': [22, 190, 343, 19],
#   'duration': 20,
#   'trip_start_time': 436.7792123679406},
#  {'start_latitude': 42.238595,
#   'start_longitude': -83.693896,
#   'destination_latitude': 42.2582907,
#   'destination_longitude': -83.6888898,
#   'path_to_store': [113, 60],
#   'path_from_store': [60, 113],
#   'duration': 20,
#   'trip_start_time': 438.3015491851803},
#  {'start_latitude': 42.319668,
#   'start_longitude': -83.700954,
#   'destination_latitude': 42.3047316,
#   'destination_longitude': -83.7087342,
#   'path_to_store': [48, 63, 354, 293, 371, 253, 40],
#   'path_from_store': [40, 253, 371, 293, 354, 63, 48],
#   'duration': 14,
#   'trip_start_time': 425.89234584153525},
#  {'start_latitude': 42.268049,
#   'start_longitude': -83.760482,
#   'destination_latitude': 42.258541,
#   'destination_longitude': -83.713074,
#   'path_to_store': [114, 407, 145, 267, 234, 64],
#   'path_from_store': [64, 234, 267, 145, 407, 114],
#   'duration': 21,
#   'trip_start_time': 116.82409119779054},
#  {'start_latitude': 42.278507,
#   'start_longitude': -83.768023,
#   'destination_latitude': 42.2849389,
#   'destination_longitude': -83.7816983,
#   'path_to_store': [4, 55],
#   'path_from_store': [55, 4],
#   'duration': 19,
#   'trip_start_time': 260.9695231128419},
#  {'start_latitude': 42.265292,
#   'start_longitude': -83.772085,
#   'destination_latitude': 42.2774847,
#   'destination_longitude': -83.7822065,
#   'path_to_store': [416, 32, 343, 190, 22],
#   'path_from_store': [22, 190, 343, 32, 416],
#   'duration': 20,
#   'trip_start_time': 181.43163457257052},
#  {'start_latitude': 42.300071,
#   'start_longitude': -83.736388,
#   'destination_latitude': 42.3047316,
#   'destination_longitude': -83.7087342,
#   'path_to_store': [177, 330, 420, 334, 40],
#   'path_from_store': [40, 334, 420, 330, 177],
#   'duration': 21,
#   'trip_start_time': 105.67141314337658},
#  {'start_latitude': 42.271875,
#   'start_longitude': -83.751555,
#   'destination_latitude': 42.258541,
#   'destination_longitude': -83.713074,
#   'path_to_store': [192, 204, 267, 234, 64],
#   'path_from_store': [64, 234, 267, 204, 192],
#   'duration': 19,
#   'trip_start_time': 221.2528912291291},
#  {'start_latitude': 42.261211,
#   'start_longitude': -83.780196,
#   'destination_latitude': 42.2774847,
#   'destination_longitude': -83.7822065,
#   'path_to_store': [32, 343, 190, 22],
#   'path_from_store': [22, 190, 343, 32],
#   'duration': 16,
#   'trip_start_time': 195.06776178716066},
#  {'start_latitude': 42.312935,
#   'start_longitude': -83.733398,
#   'destination_latitude': 42.3047316,
#   'destination_longitude': -83.7087342,
#   'path_to_store': [54, 177, 330, 420, 334, 40],
#   'path_from_store': [40, 334, 420, 330, 177, 54],
#   'duration': 10,
#   'trip_start_time': 164.03695811581912},
#  {'start_latitude': 42.236071,
#   'start_longitude': -83.712772,
#   'destination_latitude': 42.258541,
#   'destination_longitude': -83.713074,
#   'path_to_store': [241, 53, 347, 234, 64],
#   'path_from_store': [64, 234, 347, 53, 241],
#   'duration': 23,
#   'trip_start_time': 201.46235836485388},
#  {'start_latitude': 42.313932,
#   'start_longitude': -83.725099,
#   'destination_latitude': 42.3047316,
#   'destination_longitude': -83.7087342,
#   'path_to_store': [54, 177, 330, 420, 334, 40],
#   'path_from_store': [40, 334, 420, 330, 177, 54],
#   'duration': 25,
#   'trip_start_time': 195.7102043721712},
#  {'start_latitude': 42.26775,
#   'start_longitude': -83.75184,
#   'destination_latitude': 42.258541,
#   'destination_longitude': -83.713074,
#   'path_to_store': [407, 145, 267, 234, 64],
#   'path_from_store': [64, 234, 267, 145, 407],
#   'duration': 13,
#   'trip_start_time': 391.34721077238584},
#  {'start_latitude': 42.290885,
#   'start_longitude': -83.731004,
#   'destination_latitude': 42.3047316,
#   'destination_longitude': -83.7087342,
#   'path_to_store': [285, 164, 8, 9, 226, 281, 218, 334, 40],
#   'path_from_store': [40, 334, 218, 281, 226, 9, 8, 164, 285],
#   'duration': 24,
#   'trip_start_time': 344.8913520503743},
#  {'start_latitude': 42.287099,
#   'start_longitude': -83.761733,
#   'destination_latitude': 42.2849389,
#   'destination_longitude': -83.7816983,
#   'path_to_store': [156, 329, 4, 55],
#   'path_from_store': [55, 4, 329, 156],
#   'duration': 24,
#   'trip_start_time': 422.58441925407425},
#  {'start_latitude': 42.292193,
#   'start_longitude': -83.753797,
#   'destination_latitude': 42.2854541,
#   'destination_longitude': -83.7788879,
#   'path_to_store': [246, 228, 65, 10, 248, 138],
#   'path_from_store': [138, 248, 10, 65, 228, 246],
#   'duration': 16,
#   'trip_start_time': 345.4240944142605},
#  {'start_latitude': 42.320088,
#   'start_longitude': -83.70143,
#   'destination_latitude': 42.3047316,
#   'destination_longitude': -83.7087342,
#   'path_to_store': [48, 63, 354, 293, 371, 253, 40],
#   'path_from_store': [40, 253, 371, 293, 354, 63, 48],
#   'duration': 13,
#   'trip_start_time': 287.46381660947094},
#  {'start_latitude': 42.260111,
#   'start_longitude': -83.723641,
#   'destination_latitude': 42.258541,
#   'destination_longitude': -83.713074,
#   'path_to_store': [234, 64],
#   'path_from_store': [64, 234],
#   'duration': 14,
#   'trip_start_time': 498.9712613625829},
#  {'start_latitude': 42.302613,
#   'start_longitude': -83.741839,
#   'destination_latitude': 42.3047316,
#   'destination_longitude': -83.7087342,
#   'path_to_store': [252, 177, 330, 420, 334, 40],
#   'path_from_store': [40, 334, 420, 330, 177, 252],
#   'duration': 15,
#   'trip_start_time': 430.37681779621784},
#  {'start_latitude': 42.27795,
#   'start_longitude': -83.742539,
#   'destination_latitude': 42.2794636,
#   'destination_longitude': -83.7405186,
#   'path_to_store': [144, 201, 129],
#   'path_from_store': [129, 201, 144],
#   'duration': 16,
#   'trip_start_time': 584.6859539710763},
#  {'start_latitude': 42.242997,
#   'start_longitude': -83.697396,
#   'destination_latitude': 42.2582907,
#   'destination_longitude': -83.6888898,
#   'path_to_store': [100, 113, 60],
#   'path_from_store': [60, 113, 100],
#   'duration': 16,
#   'trip_start_time': 123.44382538797943},
#  {'start_latitude': 42.31759,
#   'start_longitude': -83.716472,
#   'destination_latitude': 42.3047316,
#   'destination_longitude': -83.7087342,
#   'path_to_store': [385, 293, 371, 253, 40],
#   'path_from_store': [40, 253, 371, 293, 385],
#   'duration': 21,
#   'trip_start_time': 359.9932145918783},
#  {'start_latitude': 42.277623,
#   'start_longitude': -83.775502,
#   'destination_latitude': 42.2774847,
#   'destination_longitude': -83.7822065,
#   'path_to_store': [19, 343, 190, 22],
#   'path_from_store': [22, 190, 343, 19],
#   'duration': 21,
#   'trip_start_time': 169.34997271197363},
#  {'start_latitude': 42.285859,
#   'start_longitude': -83.751934,
#   'destination_latitude': 42.2849389,
#   'destination_longitude': -83.7816983,
#   'path_to_store': [264, 49, 156, 329, 4, 55],
#   'path_from_store': [55, 4, 329, 156, 49, 264],
#   'duration': 21,
#   'trip_start_time': 418.9668577342815},
#  {'start_latitude': 42.254492,
#   'start_longitude': -83.728631,
#   'destination_latitude': 42.258541,
#   'destination_longitude': -83.713074,
#   'path_to_store': [234, 64],
#   'path_from_store': [64, 234],
#   'duration': 20,
#   'trip_start_time': 148.49237485911337},
#  {'start_latitude': 42.290701,
#   'start_longitude': -83.789868,
#   'destination_latitude': 42.2849389,
#   'destination_longitude': -83.7816983,
#   'path_to_store': [178, 85, 55],
#   'path_from_store': [55, 85, 178],
#   'duration': 14,
#   'trip_start_time': 319.7316446640668},
#  {'start_latitude': 42.264344,
#   'start_longitude': -83.76906,
#   'destination_latitude': 42.2774847,
#   'destination_longitude': -83.7822065,
#   'path_to_store': [78, 19, 343, 190, 22],
#   'path_from_store': [22, 190, 343, 19, 78],
#   'duration': 31,
#   'trip_start_time': 479.7582704815053},
#  {'start_latitude': 42.247168,
#   'start_longitude': -83.747731,
#   'destination_latitude': 42.24818,
#   'destination_longitude': -83.758339,
#   'path_to_store': [306, 180, 154, 279],
#   'path_from_store': [279, 154, 180, 306],
#   'duration': 14,
#   'trip_start_time': 327.1994953918976},
#  {'start_latitude': 42.295877,
#   'start_longitude': -83.754935,
#   'destination_latitude': 42.2854541,
#   'destination_longitude': -83.7788879,
#   'path_to_store': [228, 65, 10, 248, 138],
#   'path_from_store': [138, 248, 10, 65, 228],
#   'duration': 25,
#   'trip_start_time': 198.89937478141175},
#  {'start_latitude': 42.282776,
#   'start_longitude': -83.752967,
#   'destination_latitude': 42.2849389,
#   'destination_longitude': -83.7816983,
#   'path_to_store': [49, 156, 329, 4, 55],
#   'path_from_store': [55, 4, 329, 156, 49],
#   'duration': 13,
#   'trip_start_time': 196.84050429080492},
#  {'start_latitude': 42.268029,
#   'start_longitude': -83.760985,
#   'destination_latitude': 42.258541,
#   'destination_longitude': -83.713074,
#   'path_to_store': [114, 407, 145, 267, 234, 64],
#   'path_from_store': [64, 234, 267, 145, 407, 114],
#   'duration': 28,
#   'trip_start_time': 188.6811162384323},
#  {'start_latitude': 42.257722,
#   'start_longitude': -83.772716,
#   'destination_latitude': 42.2774847,
#   'destination_longitude': -83.7822065,
#   'path_to_store': [208, 3, 190, 22],
#   'path_from_store': [22, 190, 3, 208],
#   'duration': 16,
#   'trip_start_time': 490.27992229988394},
#  {'start_latitude': 42.281038,
#   'start_longitude': -83.695926,
#   'destination_latitude': 42.3060503,
#   'destination_longitude': -83.6910262,
#   'path_to_store': [35, 84, 96, 349, 161],
#   'path_from_store': [161, 349, 96, 84, 35],
#   'duration': 22,
#   'trip_start_time': 291.0496984450509},
#  {'start_latitude': 42.31978,
#   'start_longitude': -83.70421,
#   'destination_latitude': 42.3047316,
#   'destination_longitude': -83.7087342,
#   'path_to_store': [152, 293, 371, 253, 40],
#   'path_from_store': [40, 253, 371, 293, 152],
#   'duration': 21,
#   'trip_start_time': 310.0230274452185},
#  {'start_latitude': 42.312929,
#   'start_longitude': -83.733017,
#   'destination_latitude': 42.3047316,
#   'destination_longitude': -83.7087342,
#   'path_to_store': [54, 177, 330, 420, 334, 40],
#   'path_from_store': [40, 334, 420, 330, 177, 54],
#   'duration': 26,
#   'trip_start_time': 266.7764775595936},
#  {'start_latitude': 42.318459,
#   'start_longitude': -83.713525,
#   'destination_latitude': 42.3047316,
#   'destination_longitude': -83.7087342,
#   'path_to_store': [385, 293, 371, 253, 40],
#   'path_from_store': [40, 253, 371, 293, 385],
#   'duration': 21,
#   'trip_start_time': 277.7446659503918},
#  {'start_latitude': 42.30483,
#   'start_longitude': -83.705719,
#   'destination_latitude': 42.3047316,
#   'destination_longitude': -83.7087342,
#   'path_to_store': [334, 40],
#   'path_from_store': [40, 334],
#   'duration': 16,
#   'trip_start_time': 594.5927499838424},
#  {'start_latitude': 42.247704,
#   'start_longitude': -83.704248,
#   'destination_latitude': 42.2582907,
#   'destination_longitude': -83.6888898,
#   'path_to_store': [100, 113, 60],
#   'path_from_store': [60, 113, 100],
#   'duration': 34,
#   'trip_start_time': 432.23211894291336},
#  {'start_latitude': 42.259048,
#   'start_longitude': -83.764992,
#   'destination_latitude': 42.24818,
#   'destination_longitude': -83.758339,
#   'path_to_store': [141, 352, 170, 23, 279],
#   'path_from_store': [279, 23, 170, 352, 141],
#   'duration': 25,
#   'trip_start_time': 240.50580227939216},
#  {'start_latitude': 42.27795,
#   'start_longitude': -83.742539,
#   'destination_latitude': 42.2794636,
#   'destination_longitude': -83.7405186,
#   'path_to_store': [144, 201, 129],
#   'path_from_store': [129, 201, 144],
#   'duration': 14,
#   'trip_start_time': 460.184013401696},
#  {'start_latitude': 42.279401,
#   'start_longitude': -83.766511,
#   'destination_latitude': 42.2849389,
#   'destination_longitude': -83.7816983,
#   'path_to_store': [4, 55],
#   'path_from_store': [55, 4],
#   'duration': 17,
#   'trip_start_time': 137.88029135850257},
#  {'start_latitude': 42.290607,
#   'start_longitude': -83.791735,
#   'destination_latitude': 42.2849389,
#   'destination_longitude': -83.7816983,
#   'path_to_store': [178, 85, 55],
#   'path_from_store': [55, 85, 178],
#   'duration': 14,
#   'trip_start_time': 640.649485193803},
#  {'start_latitude': 42.287253,
#   'start_longitude': -83.688764,
#   'destination_latitude': 42.3060503,
#   'destination_longitude': -83.6910262,
#   'path_to_store': [96, 349, 161],
#   'path_from_store': [161, 349, 96],
#   'duration': 21,
#   'trip_start_time': 152.70813508206874},
#  {'start_latitude': 42.293213,
#   'start_longitude': -83.755863,
#   'destination_latitude': 42.2854541,
#   'destination_longitude': -83.7788879,
#   'path_to_store': [228, 65, 10, 248, 138],
#   'path_from_store': [138, 248, 10, 65, 228],
#   'duration': 23,
#   'trip_start_time': 658.303523217042},
#  {'start_latitude': 42.28639,
#   'start_longitude': -83.765329,
#   'destination_latitude': 42.2854541,
#   'destination_longitude': -83.7788879,
#   'path_to_store': [10, 248, 138],
#   'path_from_store': [138, 248, 10],
#   'duration': 7,
#   'trip_start_time': 282.0574050390985},
#  {'start_latitude': 42.241569,
#   'start_longitude': -83.753485,
#   'destination_latitude': 42.24818,
#   'destination_longitude': -83.758339,
#   'path_to_store': [296, 250, 279],
#   'path_from_store': [279, 250, 296],
#   'duration': 28,
#   'trip_start_time': 399.5864230880869},
#  {'start_latitude': 42.260472,
#   'start_longitude': -83.692243,
#   'destination_latitude': 42.2582907,
#   'destination_longitude': -83.6888898,
#   'path_to_store': [60],
#   'path_from_store': [60],
#   'duration': 13,
#   'trip_start_time': 539.5968116231272},
#  {'start_latitude': 42.319629,
#   'start_longitude': -83.702289,
#   'destination_latitude': 42.3047316,
#   'destination_longitude': -83.7087342,
#   'path_to_store': [152, 293, 371, 253, 40],
#   'path_from_store': [40, 253, 371, 293, 152],
#   'duration': 14,
#   'trip_start_time': 177.94078088976556},
#  {'start_latitude': 42.259387,
#   'start_longitude': -83.719026,
#   'destination_latitude': 42.258541,
#   'destination_longitude': -83.713074,
#   'path_to_store': [64],
#   'path_from_store': [64],
#   'duration': 22,
#   'trip_start_time': 440.64051787437626},
#  {'start_latitude': 42.262982,
#   'start_longitude': -83.698167,
#   'destination_latitude': 42.2579937,
#   'destination_longitude': -83.6982439,
#   'path_to_store': [106],
#   'path_from_store': [106],
#   'duration': 16,
#   'trip_start_time': 185.69913666833656},
#  {'start_latitude': 42.26014,
#   'start_longitude': -83.692898,
#   'destination_latitude': 42.2579937,
#   'destination_longitude': -83.6982439,
#   'path_to_store': [106],
#   'path_from_store': [106],
#   'duration': 17,
#   'trip_start_time': 391.788721901695},
#  {'start_latitude': 42.313028,
#   'start_longitude': -83.691675,
#   'destination_latitude': 42.3060503,
#   'destination_longitude': -83.6910262,
#   'path_to_store': [220, 344, 349, 161],
#   'path_from_store': [161, 349, 344, 220],
#   'duration': 19,
#   'trip_start_time': 133.52290043555016},
#  {'start_latitude': 42.301817,
#   'start_longitude': -83.732365,
#   'destination_latitude': 42.3047316,
#   'destination_longitude': -83.7087342,
#   'path_to_store': [177, 330, 420, 334, 40],
#   'path_from_store': [40, 334, 420, 330, 177],
#   'duration': 13,
#   'trip_start_time': 507.0757845953617},
#  {'start_latitude': 42.261119,
#   'start_longitude': -83.764145,
#   'destination_latitude': 42.24818,
#   'destination_longitude': -83.758339,
#   'path_to_store': [141, 352, 170, 23, 279],
#   'path_from_store': [279, 23, 170, 352, 141],
# ...
#   'path_to_store': [350, 289, 64],
#   'path_from_store': [64, 289, 350],
#   'duration': 21,
#   'trip_start_time': 463.82250555084187},
#  {'start_latitude': 42.281387,
#   'start_longitude': -83.774191,
#   'destination_latitude': 42.2849389,
#   'destination_longitude': -83.7816983,
#   'path_to_store': [363, 4, 55],
#   'path_from_store': [55, 4, 363],
#   'duration': 24,
#   'trip_start_time': 401.3254150588607},
#  {'start_latitude': 42.266306,
#   'start_longitude': -83.759085,
#   'destination_latitude': 42.258541,
#   'destination_longitude': -83.713074,
#   'path_to_store': [114, 407, 145, 267, 234, 64],
#   'path_from_store': [64, 234, 267, 145, 407, 114],
#   'duration': 31,
#   'trip_start_time': 489.36702479299663},
#  {'start_latitude': 42.266773,
#   'start_longitude': -83.754363,
#   'destination_latitude': 42.258541,
#   'destination_longitude': -83.713074,
#   'path_to_store': [114, 407, 145, 267, 234, 64],
#   'path_from_store': [64, 234, 267, 145, 407, 114],
#   'duration': 18,
#   'trip_start_time': 231.36388857567897},
#  {'start_latitude': 42.292525,
#   'start_longitude': -83.757426,
#   'destination_latitude': 42.2854541,
#   'destination_longitude': -83.7788879,
#   'path_to_store': [228, 65, 10, 248, 138],
#   'path_from_store': [138, 248, 10, 65, 228],
#   'duration': 25,
#   'trip_start_time': 481.3618269404027},
#  {'start_latitude': 42.307758,
#   'start_longitude': -83.74138,
#   'destination_latitude': 42.3047316,
#   'destination_longitude': -83.7087342,
#   'path_to_store': [133, 119, 252, 177, 330, 420, 334, 40],
#   'path_from_store': [40, 334, 420, 330, 177, 252, 119, 133],
#   'duration': 23,
#   'trip_start_time': 461.02392716209937},
#  {'start_latitude': 42.266084,
#   'start_longitude': -83.762638,
#   'destination_latitude': 42.258541,
#   'destination_longitude': -83.713074,
#   'path_to_store': [114, 407, 145, 267, 234, 64],
#   'path_from_store': [64, 234, 267, 145, 407, 114],
#   'duration': 11,
#   'trip_start_time': 499.035106149948},
#  {'start_latitude': 42.314998,
#   'start_longitude': -83.770086,
#   'destination_latitude': 42.2854541,
#   'destination_longitude': -83.7788879,
#   'path_to_store': [237, 71, 117, 65, 10, 248, 138],
#   'path_from_store': [138, 248, 10, 65, 117, 71, 237],
#   'duration': 19,
#   'trip_start_time': 233.08693683120313},
#  {'start_latitude': 42.277455,
#   'start_longitude': -83.755661,
#   'destination_latitude': 42.2849389,
#   'destination_longitude': -83.7816983,
#   'path_to_store': [36, 329, 4, 55],
#   'path_from_store': [55, 4, 329, 36],
#   'duration': 16,
#   'trip_start_time': 284.0366593918232},
#  {'start_latitude': 42.31329,
#   'start_longitude': -83.733825,
#   'destination_latitude': 42.3047316,
#   'destination_longitude': -83.7087342,
#   'path_to_store': [54, 177, 330, 420, 334, 40],
#   'path_from_store': [40, 334, 420, 330, 177, 54],
#   'duration': 21,
#   'trip_start_time': 263.0323064427593},
#  {'start_latitude': 42.25683,
#   'start_longitude': -83.72761,
#   'destination_latitude': 42.258541,
#   'destination_longitude': -83.713074,
#   'path_to_store': [234, 64],
#   'path_from_store': [64, 234],
#   'duration': 16,
#   'trip_start_time': 371.996022937039},
#  {'start_latitude': 42.24467,
#   'start_longitude': -83.724071,
#   'destination_latitude': 42.258541,
#   'destination_longitude': -83.713074,
#   'path_to_store': [53, 347, 234, 64],
#   'path_from_store': [64, 234, 347, 53],
#   'duration': 19,
#   'trip_start_time': 114.88096918506652},
#  {'start_latitude': 42.269543,
#   'start_longitude': -83.748402,
#   'destination_latitude': 42.258541,
#   'destination_longitude': -83.713074,
#   'path_to_store': [407, 145, 267, 234, 64],
#   'path_from_store': [64, 234, 267, 145, 407],
#   'duration': 25,
#   'trip_start_time': 168.98001458540753},
#  {'start_latitude': 42.301792,
#   'start_longitude': -83.732768,
#   'destination_latitude': 42.3047316,
#   'destination_longitude': -83.7087342,
#   'path_to_store': [177, 330, 420, 334, 40],
#   'path_from_store': [40, 334, 420, 330, 177],
#   'duration': 22,
#   'trip_start_time': 317.9699817226886},
#  {'start_latitude': 42.259184,
#   'start_longitude': -83.688997,
#   'destination_latitude': 42.2582907,
#   'destination_longitude': -83.6888898,
#   'path_to_store': [60],
#   'path_from_store': [60],
#   'duration': 22,
#   'trip_start_time': 396.10611683212386},
#  {'start_latitude': 42.239975,
#   'start_longitude': -83.723263,
#   'destination_latitude': 42.258541,
#   'destination_longitude': -83.713074,
#   'path_to_store': [241, 53, 347, 234, 64],
#   'path_from_store': [64, 234, 347, 53, 241],
#   'duration': 26,
#   'trip_start_time': 238.02434032853301},
#  {'start_latitude': 42.255786,
#   'start_longitude': -83.761135,
#   'destination_latitude': 42.24818,
#   'destination_longitude': -83.758339,
#   'path_to_store': [141, 352, 170, 23, 279],
#   'path_from_store': [279, 23, 170, 352, 141],
#   'duration': 18,
#   'trip_start_time': 122.85877054760108},
#  {'start_latitude': 42.261747,
#   'start_longitude': -83.689395,
#   'destination_latitude': 42.2582907,
#   'destination_longitude': -83.6888898,
#   'path_to_store': [60],
#   'path_from_store': [60],
#   'duration': 17,
#   'trip_start_time': 464.39326728311516},
#  {'start_latitude': 42.26028,
#   'start_longitude': -83.771992,
#   'destination_latitude': 42.2774847,
#   'destination_longitude': -83.7822065,
#   'path_to_store': [208, 3, 190, 22],
#   'path_from_store': [22, 190, 3, 208],
#   'duration': 10,
#   'trip_start_time': 511.79555299406036},
#  {'start_latitude': 42.312434,
#   'start_longitude': -83.691753,
#   'destination_latitude': 42.3060503,
#   'destination_longitude': -83.6910262,
#   'path_to_store': [344, 349, 161],
#   'path_from_store': [161, 349, 344],
#   'duration': 26,
#   'trip_start_time': 525.8025734315066},
#  {'start_latitude': 42.27795,
#   'start_longitude': -83.742539,
#   'destination_latitude': 42.2794636,
#   'destination_longitude': -83.7405186,
#   'path_to_store': [144, 201, 129],
#   'path_from_store': [129, 201, 144],
#   'duration': 23,
#   'trip_start_time': 558.6219093004239},
#  {'start_latitude': 42.312475,
#   'start_longitude': -83.691797,
#   'destination_latitude': 42.3060503,
#   'destination_longitude': -83.6910262,
#   'path_to_store': [344, 349, 161],
#   'path_from_store': [161, 349, 344],
#   'duration': 23,
#   'trip_start_time': 219.09018814433338},
#  {'start_latitude': 42.313775,
#   'start_longitude': -83.726202,
#   'destination_latitude': 42.3047316,
#   'destination_longitude': -83.7087342,
#   'path_to_store': [54, 177, 330, 420, 334, 40],
#   'path_from_store': [40, 334, 420, 330, 177, 54],
#   'duration': 16,
#   'trip_start_time': 630.9074662778024},
#  {'start_latitude': 42.271619,
#   'start_longitude': -83.752878,
#   'destination_latitude': 42.258541,
#   'destination_longitude': -83.713074,
#   'path_to_store': [192, 204, 267, 234, 64],
#   'path_from_store': [64, 234, 267, 204, 192],
#   'duration': 17,
#   'trip_start_time': 387.246835114732},
#  {'start_latitude': 42.302226,
#   'start_longitude': -83.772799,
#   'destination_latitude': 42.2854541,
#   'destination_longitude': -83.7788879,
#   'path_to_store': [273, 265, 393, 248, 138],
#   'path_from_store': [138, 248, 189, 265, 273],
#   'duration': 20,
#   'trip_start_time': 497.68989442893394},
#  {'start_latitude': 42.269374,
#   'start_longitude': -83.768024,
#   'destination_latitude': 42.2774847,
#   'destination_longitude': -83.7822065,
#   'path_to_store': [78, 19, 343, 190, 22],
#   'path_from_store': [22, 190, 343, 19, 78],
#   'duration': 17,
#   'trip_start_time': 43.22137747336763},
#  {'start_latitude': 42.286011,
#   'start_longitude': -83.747862,
#   'destination_latitude': 42.2794636,
#   'destination_longitude': -83.7405186,
#   'path_to_store': [61, 143, 14, 288, 47, 17, 129],
#   'path_from_store': [129, 17, 47, 288, 14, 143, 61],
#   'duration': 17,
#   'trip_start_time': 465.78143133180663},
#  {'start_latitude': 42.245337,
#   'start_longitude': -83.720976,
#   'destination_latitude': 42.258541,
#   'destination_longitude': -83.713074,
#   'path_to_store': [53, 347, 234, 64],
#   'path_from_store': [64, 234, 347, 53],
#   'duration': 14,
#   'trip_start_time': 412.4250002689435},
#  {'start_latitude': 42.281245,
#   'start_longitude': -83.790386,
#   'destination_latitude': 42.2860183,
#   'destination_longitude': -83.8411669,
#   'path_to_store': [188, 254, 335, 73],
#   'path_from_store': [73, 335, 254, 188],
#   'duration': 27,
#   'trip_start_time': 222.12543442624994},
#  {'start_latitude': 42.249946,
#   'start_longitude': -83.758715,
#   'destination_latitude': 42.24818,
#   'destination_longitude': -83.758339,
#   'path_to_store': [23, 279],
#   'path_from_store': [279, 23],
#   'duration': 14,
#   'trip_start_time': 613.0673185329043},
#  {'start_latitude': 42.287789,
#   'start_longitude': -83.687999,
#   'destination_latitude': 42.3060503,
#   'destination_longitude': -83.6910262,
#   'path_to_store': [96, 349, 161],
#   'path_from_store': [161, 349, 96],
#   'duration': 22,
#   'trip_start_time': 689.5652615008713},
#  {'start_latitude': 42.239506,
#   'start_longitude': -83.718759,
#   'destination_latitude': 42.258541,
#   'destination_longitude': -83.713074,
#   'path_to_store': [241, 53, 347, 234, 64],
#   'path_from_store': [64, 234, 347, 53, 241],
#   'duration': 20,
#   'trip_start_time': 300.7952785439773},
#  {'start_latitude': 42.241075,
#   'start_longitude': -83.6918,
#   'destination_latitude': 42.2582907,
#   'destination_longitude': -83.6888898,
#   'path_to_store': [113, 60],
#   'path_from_store': [60, 113],
#   'duration': 16,
#   'trip_start_time': 230.59868227862648},
#  {'start_latitude': 42.247443,
#   'start_longitude': -83.697237,
#   'destination_latitude': 42.2582907,
#   'destination_longitude': -83.6888898,
#   'path_to_store': [100, 113, 60],
#   'path_from_store': [60, 113, 100],
#   'duration': 18,
#   'trip_start_time': 97.59995400446637},
#  {'start_latitude': 42.234602,
#   'start_longitude': -83.718766,
#   'destination_latitude': 42.258541,
#   'destination_longitude': -83.713074,
#   'path_to_store': [241, 53, 347, 234, 64],
#   'path_from_store': [64, 234, 347, 53, 241],
#   'duration': 19,
#   'trip_start_time': 399.66311796368973},
#  {'start_latitude': 42.301404,
#   'start_longitude': -83.773999,
#   'destination_latitude': 42.2854541,
#   'destination_longitude': -83.7788879,
#   'path_to_store': [273, 265, 393, 248, 138],
#   'path_from_store': [138, 248, 189, 265, 273],
#   'duration': 23,
#   'trip_start_time': 518.5175824799624},
#  {'start_latitude': 42.261551,
#   'start_longitude': -83.761255,
#   'destination_latitude': 42.24818,
#   'destination_longitude': -83.758339,
#   'path_to_store': [381, 141, 352, 170, 23, 279],
#   'path_from_store': [279, 23, 170, 352, 141, 381],
#   'duration': 20,
#   'trip_start_time': 606.5726589707044},
#  {'start_latitude': 42.286906,
#   'start_longitude': -83.78557,
#   'destination_latitude': 42.2774847,
#   'destination_longitude': -83.7822065,
#   'path_to_store': [101, 257, 22],
#   'path_from_store': [22, 257, 101],
#   'duration': 24,
#   'trip_start_time': 370.73160026107445},
#  {'start_latitude': 42.259469,
#   'start_longitude': -83.768719,
#   'destination_latitude': 42.24818,
#   'destination_longitude': -83.758339,
#   'path_to_store': [141, 352, 170, 23, 279],
#   'path_from_store': [279, 23, 170, 352, 141],
#   'duration': 20,
#   'trip_start_time': 586.5186337029799},
#  {'start_latitude': 42.285075,
#   'start_longitude': -83.695666,
#   'destination_latitude': 42.3060503,
#   'destination_longitude': -83.6910262,
#   'path_to_store': [96, 349, 161],
#   'path_from_store': [161, 349, 96],
#   'duration': 20,
#   'trip_start_time': 519.8981193681752},
#  {'start_latitude': 42.287262,
#   'start_longitude': -83.681624,
#   'destination_latitude': 42.3060503,
#   'destination_longitude': -83.6910262,
#   'path_to_store': [199, 96, 349, 161],
#   'path_from_store': [161, 412, 295, 199],
#   'duration': 19,
#   'trip_start_time': 366.79550630357517},
#  {'start_latitude': 42.289068,
#   'start_longitude': -83.687045,
#   'destination_latitude': 42.3060503,
#   'destination_longitude': -83.6910262,
#   'path_to_store': [96, 349, 161],
#   'path_from_store': [161, 349, 96],
#   'duration': 29,
#   'trip_start_time': 305.7643897665536},
#  {'start_latitude': 42.30157,
#   'start_longitude': -83.737855,
#   'destination_latitude': 42.3047316,
#   'destination_longitude': -83.7087342,
#   'path_to_store': [177, 330, 420, 334, 40],
#   'path_from_store': [40, 334, 420, 330, 177],
#   'duration': 23,
#   'trip_start_time': 266.01133789624504},
#  {'start_latitude': 42.287809,
#   'start_longitude': -83.686924,
#   'destination_latitude': 42.3060503,
#   'destination_longitude': -83.6910262,
#   'path_to_store': [199, 96, 349, 161],
#   'path_from_store': [161, 412, 295, 199],
#   'duration': 26,
#   'trip_start_time': 424.8511693821838},
#  {'start_latitude': 42.264781,
#   'start_longitude': -83.728858,
#   'destination_latitude': 42.258541,
#   'destination_longitude': -83.713074,
#   'path_to_store': [234, 64],
#   'path_from_store': [64, 234],
#   'duration': 18,
#   'trip_start_time': 294.6281472497571},
#  {'start_latitude': 42.295454,
#   'start_longitude': -83.775933,
#   'destination_latitude': 42.2854541,
#   'destination_longitude': -83.7788879,
#   'path_to_store': [248, 138],
#   'path_from_store': [138, 248],
#   'duration': 21,
#   'trip_start_time': 154.67371879541372},
#  {'start_latitude': 42.295705,
#   'start_longitude': -83.77164,
#   'destination_latitude': 42.2854541,
#   'destination_longitude': -83.7788879,
#   'path_to_store': [65, 10, 248, 138],
#   'path_from_store': [138, 248, 10, 65],
#   'duration': 24,
#   'trip_start_time': 502.8626021918685},
#  {'start_latitude': 42.312499,
#   'start_longitude': -83.691823,
#   'destination_latitude': 42.3060503,
#   'destination_longitude': -83.6910262,
#   'path_to_store': [344, 349, 161],
#   'path_from_store': [161, 349, 344],
#   'duration': 17,
#   'trip_start_time': 509.97505395981995},
#  {'start_latitude': 42.318459,
#   'start_longitude': -83.696263,
#   'destination_latitude': 42.3060503,
#   'destination_longitude': -83.6910262,
#   'path_to_store': [316, 386, 103, 277, 161],
#   'path_from_store': [161, 277, 103, 386, 316],
#   'duration': 22,
#   'trip_start_time': 647.9546296746037},
#  {'start_latitude': 42.2789,
#   'start_longitude': -83.752183,
#   'destination_latitude': 42.2849389,
#   'destination_longitude': -83.7816983,
#   'path_to_store': [30, 36, 329, 4, 55],
#   'path_from_store': [55, 4, 329, 36, 30],
#   'duration': 12,
#   'trip_start_time': 524.016912761698},
#  {'start_latitude': 42.251915,
#   'start_longitude': -83.752373,
#   'destination_latitude': 42.24818,
#   'destination_longitude': -83.758339,
#   'path_to_store': [170, 23, 279],
#   'path_from_store': [279, 23, 170],
#   'duration': 15,
#   'trip_start_time': 298.4378344480283},
#  {'start_latitude': 42.250448,
#   'start_longitude': -83.704392,
#   'destination_latitude': 42.2582907,
#   'destination_longitude': -83.6888898,
#   'path_to_store': [261, 100, 113, 60],
#   'path_from_store': [60, 113, 100, 261],
#   'duration': 21,
#   'trip_start_time': 516.0709063461346},
#  {'start_latitude': 42.290632,
#   'start_longitude': -83.785643,
#   'destination_latitude': 42.2854541,
#   'destination_longitude': -83.7788879,
#   'path_to_store': [248, 138],
#   'path_from_store': [138, 248],
#   'duration': 20,
#   'trip_start_time': 326.5959773031615},
#  {'start_latitude': 42.29008,
#   'start_longitude': -83.695709,
#   'destination_latitude': 42.3060503,
#   'destination_longitude': -83.6910262,
#   'path_to_store': [96, 349, 161],
#   'path_from_store': [161, 349, 96],
#   'duration': 26,
#   'trip_start_time': 149.0521445024022},
#  {'start_latitude': 42.280306,
#   'start_longitude': -83.746996,
#   'destination_latitude': 42.2794636,
#   'destination_longitude': -83.7405186,
#   'path_to_store': [151, 186, 123, 17, 129],
#   'path_from_store': [129, 17, 123, 186, 151],
#   'duration': 20,
#   'trip_start_time': 162.7085275274354},
#  {'start_latitude': 42.253592,
#   'start_longitude': -83.769558,
#   'destination_latitude': 42.24818,
#   'destination_longitude': -83.758339,
#   'path_to_store': [57, 250, 279],
#   'path_from_store': [279, 250, 57],
#   'duration': 25,
#   'trip_start_time': 287.7487135807185},
#  {'start_latitude': 42.257742,
#   'start_longitude': -83.730136,
#   'destination_latitude': 42.258541,
#   'destination_longitude': -83.713074,
#   'path_to_store': [234, 64],
#   'path_from_store': [64, 234],
#   'duration': 16,
#   'trip_start_time': 428.40123211602196},
#  ...]
