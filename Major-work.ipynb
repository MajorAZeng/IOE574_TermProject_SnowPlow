# %% [markdown]
# #### Module 0 Map Generation

# %%
from M0_Class_Map_Road import Map

# %%
# Create a based map
M = Map('Data/AA_Map_Final.gpkg')
# Experience a snow event
M.Experience_Snow(6)

# %% [markdown]
# #### Module 1 Trip Simulation

# %%
from M1_Trip_Generation_Module import Generate_Trips

# %%
# Generate trips
Generate_Trips(M, 'Data/your_locations.csv', 'Data/your_destinations.csv')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/st/p61yvtyx4nqbt72_8dghyfqm0000gn/T/ipykernel_85686/4160984826.py in ?()
# ----> 2 # Generate trips
#       3 Generate_Trips(M, 'Data/your_locations.csv', 'Data/your_destinations.csv')
#
# ~/Documents/Michigan Records/2023.1 Fall/IOE 574 Simulation Design and Analysis/Term Project/Model-Git/IOE574_TermProject_SnowPlow/Major-Revised-Model/M1_Trip_Generation_Module.py in ?(Map, ori_path, des_path)
#      69             'return_distance': min_distance  # Assuming return distance is the same as the original trip distance
#      70         }
#      71
#      72         # Add the trip and return trip data to the DataFrame
# ---> 73         all_trips_df = all_trips_df.append({
#      74             'start_latitude': location.latitude,
#      75             'start_longitude': location.longitude,
#      76             'destination_latitude': closest_destination.latitude,
#
# ~/anaconda3/envs/sim_term_proj_env/lib/python3.9/site-packages/pandas/core/generic.py in ?(self, name)
#    5985             and name not in self._accessors
#    5986             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5987         ):
#    5988             return self[name]
# -> 5989         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'append'

# %% [markdown]
# #### Module 2 Plowing Simulation

# %%
from M2_Plowing_Simulatoin_Module import Fack_Plow_Simulation

# %%
# Simulation Plowing Time
Fack_Plow_Simulation(M)

# %%
M.graph.edges
# Out:
# EdgeView([(119, 133), (119, 417), (119, 394), (119, 413), (119, 252), (133, 309), (133, 125), (133, 413), (309, 252), (417, 413), (394, 209), (413, 331), (252, 177), (228, 65), (228, 246), (65, 10), (65, 117), (10, 248), (10, 156), (334, 40), (334, 218), (334, 420), (334, 253), (40, 253), (218, 281), (218, 420), (218, 349), (420, 330), (253, 371), (178, 259), (178, 189), (178, 52), (178, 85), (259, 365), (259, 189), (259, 82), (365, 270), (365, 12), (365, 102), (189, 265), (189, 248), (270, 150), (270, 82), (270, 132), (150, 157), (82, 265), (82, 273), (82, 132), (132, 117), (265, 393), (265, 273), (393, 248), (273, 117), (128, 210), (128, 414), (128, 103), (128, 277), (128, 249), (128, 15), (210, 313), (210, 249), (414, 313), (414, 169), (313, 412), (313, 240), (103, 277), (103, 386), (236, 89), (236, 403), (236, 318), (236, 75), (236, 280), (89, 173), (89, 197), (89, 280), (89, 263), (89, 384), (173, 31), (173, 21), (280, 318), (403, 304), (403, 263), (403, 37), (318, 75), (318, 29), (75, 304), (75, 29), (304, 284), (304, 181), (304, 44), (304, 38), (304, 389), (234, 64), (234, 347), (234, 267), (234, 66), (64, 289), (64, 319), (289, 7), (289, 346), (289, 350), (347, 53), (347, 50), (53, 241), (53, 238), (53, 50), (117, 209), (117, 71), (209, 149), (209, 1), (209, 74), (209, 337), (149, 74), (149, 221